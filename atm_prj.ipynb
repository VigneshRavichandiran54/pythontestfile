# %%
print("""welcome to the viki atm """)
print(" ")
acc=int(input("Enter acc num : "))
ps=int(input("password : "))
             

Acc={1:11,2:22,3:33,4:44,5:55,6:66}

'''def n(a):
    name={1:"viki",2:"figi",3:"hiki"}
    if a in name:
        if a== name.keys():
             return '''
     
if acc in Acc:
    if ps in Acc.values():
        print("Welcome {}".format(acc))
        print(''' ''')
        print("1- for deposite")
        print("2 -for balance check")
        print("3 - for exit ")
        print(f"enter your choice")
        c= int(input())
        
        if c==1 :
            
        
        
        
        
        
        
        
    else:
        print("incorret password")
else:
    print("enter correct acc number  ")
# Out:
# welcome to the viki atm
#
# Enter acc num : 5
# password : 55
# Welcome 5
#
# 1- for deposite
# 2 -for balance check
# 3 - for exit
# enter your choice
# 1

# %%
help(dict)
# Out:
# Help on class dict in module builtins:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Built-in subclasses:
#  |      StgDict
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
# ...
