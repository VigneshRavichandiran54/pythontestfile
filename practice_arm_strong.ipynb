# %%
arm_num=[]
not_armnum=[]
def arm(i):
    num=i
    temp=num
    c=0
    print(arm_num)
    while num > 0 :
        r=num % 10
        c =c + (r*r*r)
        num=num // 10
        
    if (c==temp):
        
        arm_num.append(temp)
    else:
        not_armnum.append(temp)
        
    print(arm_num)

# %%
for i in range(0,200):
    print(arm(i))
# Out:
# [0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153]
# [0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0]
# None
# [0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0]
# [0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1]
# None
# [0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1]
# [0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1]
# None
# [0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1]
# [0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1]
# None
# [0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1]
# [0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1]
# None
# [0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1]
# [0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1]
# None
# [0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1]
# [0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1]
# None
# [0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1, 153, 0, 1]
# ...
